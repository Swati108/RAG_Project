# %%
from langchain_community.document_loaders import PyPDFLoader
loader=PyPDFLoader("OPERATING SYSTEMS (R15A0513).pdf")
loader
docs= loader.load()
docs
# Out:
# [Document(metadata={'producer': 'Microsoft® Word 2016', 'creator': 'Microsoft® Word 2016', 'creationdate': '2018-06-18T08:43:59+00:00', 'moddate': '2018-06-18T08:43:59+00:00', 'source': 'OPERATING SYSTEMS (R15A0513).pdf', 'total_pages': 42, 'page': 0, 'page_label': '1'}, page_content='DIGITAL NOTES   \nON   \nOPERATING SYSTEMS  \n  \n  \n  \n  \n  \n  \n    \nB.TECH III YEAR - I SEM \n(2018-19)    \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \nDEPARTMENT OF INFORMATION TECHNOLOGY  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \nMALLA REDDY COLLEGE OF ENGINEERING & TECHNOLOGY \n(Autonomous Institution – UGC, Govt. of India)  \n(Affiliated to JNTUH, Hyderabad, Approved by AICTE - Accredited by NBA & NAAC – ‘A’ Grade - ISO 9001:2015 Certified)  \nMaisammaguda, Dhulapally (Post Via. Hakimpet), Secunderabad – 500100, Telangana State, INDIA.   \n  \n    \nOPERATING SYSTEMS  Page 1'),
# ...

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
chunks= text_splitter.split_documents(docs)
chunks
# Out:
# [Document(metadata={'producer': 'Microsoft® Word 2016', 'creator': 'Microsoft® Word 2016', 'creationdate': '2018-06-18T08:43:59+00:00', 'moddate': '2018-06-18T08:43:59+00:00', 'source': 'OPERATING SYSTEMS (R15A0513).pdf', 'total_pages': 42, 'page': 0, 'page_label': '1'}, page_content='DIGITAL NOTES   \nON   \nOPERATING SYSTEMS  \n  \n  \n  \n  \n  \n  \n    \nB.TECH III YEAR - I SEM \n(2018-19)    \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \nDEPARTMENT OF INFORMATION TECHNOLOGY  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \n  \nMALLA REDDY COLLEGE OF ENGINEERING & TECHNOLOGY \n(Autonomous Institution – UGC, Govt. of India)  \n(Affiliated to JNTUH, Hyderabad, Approved by AICTE - Accredited by NBA & NAAC – ‘A’ Grade - ISO 9001:2015 Certified)  \nMaisammaguda, Dhulapally (Post Via. Hakimpet), Secunderabad – 500100, Telangana State, INDIA.   \n  \n    \nOPERATING SYSTEMS  Page 1'),
# ...

# %%
from sentence_transformers import SentenceTransformer

texts = [chunk.page_content for chunk in chunks]
if not texts:
    raise ValueError("No valid text found in the documents.")

model_transformer = SentenceTransformer("all-MiniLM-L6-v2")
embeddings = model_transformer.encode(texts)
embeddings
# Out:
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2516.23it/s]
# array([[-0.08572387, -0.01663559, -0.05665954, ..., -0.0105009 ,
#          0.02221206,  0.01547356],
#        [-0.02518291,  0.01973608, -0.05869219, ...,  0.02306681,
#         -0.04114003,  0.00939174],
#        [-0.06725576, -0.0014023 , -0.13631597, ...,  0.0539182 ,
#         -0.0261788 ,  0.01558297],
#        ...,
#        [ 0.00636742,  0.05728627, -0.03613779, ...,  0.03146537,
#          0.08267373,  0.00357499],
#        [-0.08883629,  0.08970256, -0.02317947, ...,  0.00700076,
#          0.13322449,  0.01628518],
#        [-0.10666717,  0.04854795, -0.01694374, ..., -0.01252487,
#          0.09123465, -0.02275703]], shape=(162, 384), dtype=float32)

# %%
from langchain_community.vectorstores import FAISS
from langchain_community.embeddings import HuggingFaceEmbeddings
embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
db = FAISS.from_documents(chunks, embeddings)
db
# Out:
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 2848.10it/s]

# %%
context_chunks = db.as_retriever(search_type="similarity", search_kwargs={"k": 5})

retrieved_docs = context_chunks.invoke("SYSTEM CALLS  ")

len(retrieved_docs)
# Out:
# 5

# %%
import google.generativeai as genai

# Create the model object first
# Using 'gemini-1.5-flash' as the correct model name
llm= genai.GenerativeModel('gemini-3.6-flash')

# %%
from langchain_core.prompts import ChatPromptTemplate
print(type(retrieved_docs))
# Correctly iterates, assigning each Document to 'doc'
context = "\n\n".join([doc.page_content for doc in retrieved_docs])
# context = "\n\n".join([doc.page_content for doc, i in retrieved_docs])
# context = "\n".join(context_chunks)
prompt=ChatPromptTemplate.from_template("""Answer  the question based on the context provided.
think step by step and if you don't know the answer, just say that you don't know, don't try to make up an answer.
give the user a complete and concise answer.and use a bit your mind also to elaborate the answer in easy way.
i'll tip you $1000 if user finds your answer hepful.
<context>
{context}
</context>
Question: {input} """)
context
# Out:
# <class 'list'>
# ...

# %%
from langchain_classic.chains.combine_documents import create_stuff_documents_chain
from langchain_google_genai import ChatGoogleGenerativeAI
import os
from dotenv import load_dotenv
load_dotenv()
api_key = os.getenv("GOOGLE_API_KEY")
print(api_key)
# This object IS compatible with LangChain chains
llm = ChatGoogleGenerativeAI(model="gemini-3.6-flash", google_api_key=api_key)

# Now you can use this 'llm' object in your chain
document_chain = create_stuff_documents_chain(llm, prompt)

document_chain
# Out:
# AIzaSyDA6YZRjjBccG2RKysevfXgOCZDmZ7mVXM
# RunnableBinding(bound=RunnableBinding(bound=RunnableAssign(mapper={
#   context: RunnableLambda(format_docs)
# }), kwargs={}, config={'run_name': 'format_inputs'}, config_factories=[])
# | ChatPromptTemplate(input_variables=['context', 'input'], input_types={}, partial_variables={}, messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['context', 'input'], input_types={}, partial_variables={}, template="Answer  the question based on the context provided.\nthink step by step and if you don't know the answer, just say that you don't know, don't try to make up an answer.\ngive the user a complete and concise answer.and use a bit your mind also to elaborate the answer in easy way.\ni'll tip you $1000 if user finds your answer hepful.\n<context>\n{context}\n</context>\nQuestion: {input} "), additional_kwargs={})])
# ...

# %%
"""
Retrievers: A retriever is an interface that returns documents given
 an unstructured query. It is more general than a vector store.
 A retriever does not need to be able to store documents, only to 
 return (or retrieve) them. Vector stores can be used as the backbone
 of a retriever, but there are other types of retrievers as well. 
 https://python.langchain.com/docs/modules/data_connection/retrievers/   
"""

retriever=db.as_retriever()
retriever
# Out:
# VectorStoreRetriever(tags=['FAISS', 'HuggingFaceEmbeddings'], vectorstore=<langchain_community.vectorstores.faiss.FAISS object at 0x00000212B8773110>, search_kwargs={})

# %%
from langchain_classic.chains import create_retrieval_chain
document_chain = create_stuff_documents_chain(llm, prompt)
Answers=create_retrieval_chain(retriever,document_chain)	
response=Answers.invoke({"input":"explain all system calls briefly"})

# %%
response['answer']
# Out:
# "Based on the provided context, system calls serve as an interface between user programs and the operating system. They are grouped into **six major categories**:\n\n---\n\n### 1. **Process Control**\nManages program execution and halting.\n* **`end()`**: Halts a running program normally.\n* **`abort()`**: Halts a program abnormally if an error occurs. This often generates an error trap and writes a memory dump to the disk to help debug errors.\n\n---\n\n### 2. **File Management**\nHandles operations on files (which require the file's name).\n* **`create()`**: Makes a new file.\n* **`delete()`**: Removes an existing file.\n\n---\n\n### 3. **Device Manipulation**\nControls hardware devices after they are requested and allocated.\n* **`read()`**: Reads data from a device.\n* **`write()`**: Writes data to a device.\n* **`reposition()`**: Repositions the device (similar to how file positions are moved).\n\n---\n\n### 4. **Information Maintenance**\nTransfers information between the user 
# ...
